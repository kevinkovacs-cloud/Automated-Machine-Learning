# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:15px;color:#34656d;font-family:'Comic Sans MS';text-align:center;border-radius:5px 5px;">
# <strong>_____________________________________________________________</strong></p>

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:25px;color:#34656d;font-family:'Comic Sans MS';text-align:center;border-radius:5px 5px;">
# <strong>AutoViz</strong></p>

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:15px;color:#34656d;font-family:'Comic Sans MS';text-align:left;border-radius:5px 5px;">
# <strong>AutoViz realiza la visualización automática de cualquier conjunto de datos con una línea</strong></p>

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:15px;color:#34656d;font-family:'Comic Sans MS';text-align:left;border-radius:5px;">
# <strong>Artículo con ejemplo de uso:</strong>
# <a href="https://towardsdatascience.com/autoviz-a-new-tool-for-automated-visualization-ec9c1744a6ad" target=\"_blank\">AutoViz: A New Tool for Automated Visualization</a>
# </p>

# %%
import matplotlib
print(f'Matplotlib version: {matplotlib.__version__}')
# Out:
# Matplotlib version: 3.7.3

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# Out:
# Imported v0.1.806. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
AV = AutoViz_Class()

# %%
# %matplotlib inline
df = AV.AutoViz('./data/vgsales.csv')
# Out:
# Shape of your Data Set loaded: (16598, 11)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  6
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  2
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  1
#     Number of NLP String Columns =  1
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     11 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Rank']
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_b9e86_row0_col0, #T_b9e86_row0_col2, #T_b9e86_row0_col3, #T_b9e86_row0_col4, #T_b9e86_row0_col5, #T_b9e86_row1_col0, #T_b9e86_row1_col2, #T_b9e86_row1_col3, #T_b9e86_row1_col4, #T_b9e86_row1_col5, #T_b9e86_row2_col0, #T_b9e86_row2_col2, #T_b9e86_row2_col3, #T_b9e86_row2_col4, #T_b9e86_row2_col5, #T_b9e86_row3_col0, #T_b9e86_row3_col2, #T_b9e86_row3_col3, #T_b9e86_row3_col4, #T_b9e86_row3_col5, #T_b9e86_row4_col0, #T_b9e86_row4_col2, #T_b9e86_row4_col3, #T_b9e86_row4_col4, #T_b9e86_row4_col5, #T_b9e86_row5_col0, #T_b9e86_row5_col2, #T_b9e86_row5_col3, #T_b9e86_row5_col4, #T_b9e86_row5_col5, #T_b9e86_row6_col0, #T_b9e86_row6_col2, #T_b9e86_row6_col3, #T_b9e86_row6_col4, #T_b9e86_row6_col5, #T_b9e86_row7_col0, #T_b9e86_row7_col2, #T_b9e86_row7_col3, #T_b9e86_row7_col4, #T_b9e86_row7_col5, #T_b9e86_row8_col0, #T_b9e86_row8_col2, #T_b9e86_row8_col3, #T_b9e86_row8_col4, #T_b9e86_row8_col5, #T_b9e86_row9_col0, #T_b9e86_row9_col2, #T_b9e86_row9_col3, #T_b9e86_row9_col4, #T_b9e86_row9_col5, #T_b9e86_row10_col0, #T_b9e86_row10_col2, #T_b9e86_row10_col3, #T_b9e86_row10_col4, #T_b9e86_row10_col5 {
#   font-family: Segoe UI;
# }
# #T_b9e86_row0_col1, #T_b9e86_row1_col1, #T_b9e86_row2_col1, #T_b9e86_row4_col1, #T_b9e86_row6_col1, #T_b9e86_row7_col1, #T_b9e86_row8_col1, #T_b9e86_row9_col1, #T_b9e86_row10_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_b9e86_row3_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_b9e86_row5_col1 {
#   background-color: #fdc6b0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_b9e86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9e86_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_b9e86_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_b9e86_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_b9e86_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_b9e86_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_b9e86_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9e86_level0_row0" class="row_heading level0 row0" >Rank</th>
#       <td id="T_b9e86_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_b9e86_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_b9e86_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_b9e86_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_b9e86_row0_col4" class="data row0 col4" >16600.000000</td>
#       <td id="T_b9e86_row0_col5" class="data row0 col5" >Possible ID column: drop before modeling step.</td>
#     </tr>
#     <tr>
#       <th id="T_b9e86_level0_row1" class="row_heading level0 row1" >Name</th>
#       <td id="T_b9e86_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_b9e86_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_b9e86_row1_col2" class="data row1 col2" >69</td>
#       <td id="T_b9e86_row1_col3" class="data row1 col3" ></td>
#       <td id="T_b9e86_row1_col4" class="data row1 col4" ></td>
#       <td id="T_b9e86_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_b9e86_level0_row2" class="row_heading level0 row2" >Platform</th>
#       <td id="T_b9e86_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_b9e86_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_b9e86_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_b9e86_row2_col3" class="data row2 col3" ></td>
#       <td id="T_b9e86_row2_col4" class="data row2 col4" ></td>
#       <td id="T_b9e86_row2_col5" class="data row2 col5" >13 rare categories: Too many to list. Group them into a single category or drop the categories.</td>
#     </tr>
#     <tr>
#       <th id="T_b9e86_level0_row3" class="row_heading level0 row3" >Year</th>
#       <td id="T_b9e86_row3_col0" class="data row3 col0" >float64</td>
#       <td id="T_b9e86_row3_col1" class="data row3 col1" >1.632727</td>
#       <td id="T_b9e86_row3_col2" class="data row3 col2" >NA</td>
#       <td id="T_b9e86_row3_col3" class="data row3 col3" >1980.000000</td>
#       <td id="T_b9e86_row3_col4" class="data row3 col4" >2020.000000</td>
#       <td id="T_b9e86_row3_col5" class="data row3 col5" >271 missing values. Impute them with mean, median, mode, or a constant value such as 123., Column has 305 outliers greater than upper bound (2020.50) or lower than lower bound(1992.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_b9e86_level0_row4" class="row_heading level0 row4" >Genre</th>
#       <td id="T_b9e86_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_b9e86_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_b9e86_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_b9e86_row4_col3" class="data row4 col3" ></td>
#       <td id="T_b9e86_row4_col4" class="data row4 col4" ></td>
#       <td id="T_b9e86_row4_col5" class="data row4 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_b9e86_level0_row5" class="row_heading level0 row5" >Publisher</th>
#       <td id="T_b9e86_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_b9e86_row5_col1" class="data row5 col1" >0.349440</td>
#       <td id="T_b9e86_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_b9e86_row5_col3" class="data row5 col3" ></td>
#       <td id="T_b9e86_row5_col4" class="data row5 col4" ></td>
#       <td id="T_b9e86_row5_col5" class="data row5 col5" >58 missing values. Impute them with mean, median, mode, or a constant value such as 123., Mixed dtypes: has 2 different data types:  object, float,, Possible high cardinality column with 578 unique values: Use hash encoding or text embedding to reduce dimension.</td>
#     </tr>
#     <tr>
#       <th id="T_b9e86_level0_row6" class="row_heading level0 row6" >NA_Sales</th>
#       <td id="T_b9e86_row6_col0" class="data row6 col0" >float64</td>
#       <td id="T_b9e86_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_b9e86_row6_col2" class="data row6 col2" >NA</td>
#       <td id="T_b9e86_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_b9e86_row6_col4" class="data row6 col4" >41.490000</td>
#       <td id="T_b9e86_row6_col5" class="data row6 col5" >Column has 1681 outliers greater than upper bound (0.60) or lower than lower bound(-0.36). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_b9e86_level0_row7" class="row_heading level0 row7" >EU_Sales</th>
#       <td id="T_b9e86_row7_col0" class="data row7 col0" >float64</td>
#       <td id="T_b9e86_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_b9e86_row7_col2" class="data row7 col2" >NA</td>
#       <td id="T_b9e86_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_b9e86_row7_col4" class="data row7 col4" >29.020000</td>
#       <td id="T_b9e86_row7_col5" class="data row7 col5" >Column has 2081 outliers greater than upper bound (0.28) or lower than lower bound(-0.17). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_b9e86_level0_row8" class="row_heading level0 row8" >JP_Sales</th>
#       <td id="T_b9e86_row8_col0" class="data row8 col0" >float64</td>
#       <td id="T_b9e86_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_b9e86_row8_col2" class="data row8 col2" >NA</td>
#       <td id="T_b9e86_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_b9e86_row8_col4" class="data row8 col4" >10.220000</td>
#       <td id="T_b9e86_row8_col5" class="data row8 col5" >Column has 2425 outliers greater than upper bound (0.10) or lower than lower bound(-0.06). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_b9e86_level0_row9" class="row_heading level0 row9" >Other_Sales</th>
#       <td id="T_b9e86_row9_col0" class="data row9 col0" >float64</td>
#       <td id="T_b9e86_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id=
# Number of All Scatter Plots = 21
# Could not draw Distribution Plot
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to C:\nltk_data...
# [nltk_data]    |   Unzipping corpora\cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to C:\nltk_data...
# [nltk_data]    |   Unzipping corpora\gazetteers.zip.
# [nltk_data]    | Downloading package genesis to C:\nltk_data...
# [nltk_data]    |   Unzipping corpora\genesis.zip.
# [nltk_data]    | Downloading package gutenberg to C:\nltk_data...
# [nltk_data]    |   Unzipping corpora\gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to C:\nltk_data...
# [nltk_data]    |   Unzipping corpora\inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to C:\nltk_data...
# [nltk_data]    |   Unzipping corpora\movie_reviews.zip.
# [nltk_data]    | Downloading package names to C:\nltk_data...
# [nltk_data]    |   Unzipping corpora\names.zip.
# [nltk_data]    | Downloading package shakespeare to C:\nltk_data...
# [nltk_data]    |   Unzipping corpora\shakespeare.zip.
# [nltk_data]    | Downloading package stopwords to C:\nltk_data...
# [nltk_data]    |   Unzipping corpora\stopwords.zip.
# [nltk_data]    | Downloading package treebank to C:\nltk_data...
# [nltk_data]    |   Unzipping corpora\treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\nltk_data...
# [nltk_data]    |   Unzipping corpora\twitter_samples.zip.
# [nltk_data]    | Downloading package omw to C:\nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to C:\nltk_data...
# [nltk_data]    | Downloading package wordnet to C:\nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to C:\nltk_data...
# [nltk_data]    | Downloading package wordnet31 to C:\nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to C:\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet_ic.zip.
# [nltk_data]    | Downloading package words to C:\nltk_data...
# [nltk_data]    |   Unzipping corpora\words.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\nltk_data...
# [nltk_data]    |   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to C:\nltk_data...
# [nltk_data]    |   Unzipping tokenizers\punkt.zip.
# [nltk_data]    | Downloading package snowball_data to C:\nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\nltk_data...
# [nltk_data]    |   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\Admin/nltk_data'
#     - 'h:\\Anaconda3Env\\Pycaret\\nltk_data'
#     - 'h:\\Anaconda3Env\\Pycaret\\share\\nltk_data'
#     - 'h:\\Anaconda3Env\\Pycaret\\lib\\nltk_data'
#     - 'C:\\Users\\Admin\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
# Could not draw wordcloud plot for Name
#
# **********************************************************************
#   Resource punkt_tab not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt_tab/english/
#
#   Searched in:
#     - 'C:\\Users\\Admin/nltk_data'
#     - 'h:\\Anaconda3Env\\Pycaret\\nltk_data'
#     - 'h:\\Anaconda3Env\\Pycaret\\share\\nltk_data'
#     - 'h:\\Anaconda3Env\\Pycaret\\lib\\nltk_data'
#     - 'C:\\Users\\Admin\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
# Could not draw wordcloud plot for Publisher
# All Plots done
# Time to run AutoViz = 86 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:15px;color:#34656d;font-family:'Comic Sans MS';text-align:center;border-radius:5px 5px;">
# <strong>_____________________________________________________________</strong></p>

# %% [markdown]
# <a id = "1.0"></a>
# <p style="font-size:15px;color:#34656d;font-family:'Comic Sans MS';text-align:center;border-radius:5px 5px;">
# <strong>_____________________________________________________________</strong></p>
